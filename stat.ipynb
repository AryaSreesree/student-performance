# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as stat

# %%
df=pd.read_csv("sp.csv")
df.head(4)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
df["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#There are 518 females and 482 males
sns.countplot(x="gender" , data=df, color="green")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="parental level of education" , data=df, color="purple")
plt.xticks(rotation=90)
plt.show()

# %%
# about 25% of the parents have gone to college, accquired associate degree.
#parents with masters degree is only 50 in number.

# %%
df["test preparation course"].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
#k= df["math score"]+df["reading score"]+df["writing score"]
#df["Mean"]= k/3

# %%
df["Mean"]= df[['math score','reading score','writing score']].mean(axis=1)

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score       Mean
# 0                    none           0             17             10   9.000000
# 1                    none           8             24             23  18.333333

# %%
#ax= sns.barplot(x="gender" , y="Mean", data=df)
#ax.bar_label(ax.containers[0])

# %%
sns.barplot(x="gender" , y="Mean", data=df)
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x="test preparation course" , y="Mean", data=df)
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
ddf=df.drop(columns=['Mean'])

# %%
table= pd.pivot_table(data=ddf, index=["gender"],aggfunc=np.mean)
table
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
table.plot(kind="bar");

# %%
tablee= pd.pivot_table(data=ddf, index=["test preparation course"])
tablee
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
tablee.plot(kind="bar");

# %%
sns.boxplot(x="math score" , data=df)

# %%
df1=ddf.sort_values(by=["math score"],ascending= False)
df1.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# 997    male        group D                some college      standard
# 995    male        group E                some college      standard
# 513  female        group E           bachelor's degree      standard
# 514  female        group E                 high school      standard
# 994    male        group C          associate's degree      standard
# 993    male        group C                some college      standard
# 512  female        group D                some college      standard
# ...
